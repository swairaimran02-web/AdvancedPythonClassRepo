# %%
SYSTEM_VERSION = "1.0.0"

name = input("Enter your name: ")
location = input("Enter your location: ")


welcome_message = "Hello " + name + " from " + location + "! " \
                  "Welcome to our system (Version " + SYSTEM_VERSION + ")."

print(welcome_message)
# Out:
# Hello swaira from Lahore! Welcome to our system (Version 1.0.0).
