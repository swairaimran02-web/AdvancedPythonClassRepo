# %%
from IPython.terminal.shortcuts.auto_suggest import accept_or_jump_to_end
#
# read questions from csv
# prepare 5-10 questions for a quiz
# a user will come and enter his name and take quiz
# one usser cannot tak equiz twice
# save user score in a different csv named as student score
if a student fail in any question game will be end instantly

# %%
import csv
import random as r
questions = []
with open("QuestionareDummy.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        questions.append(row)
quiz_questions = r.sample(questions, 5)
name = input("Enter your name: ").strip()
# Out:
# [{'Question': "Which programming language is known as the 'mother of all languages'?",
#   'Option A': 'Python',
#   'Option B': 'C',
#   'Option C': 'Java',
#   'Option D': 'Assembly',
#   'Right Answer': 'B'},
#  {'Question': 'What is the capital city of Japan?',
#   'Option A': 'Seoul',
#   'Option B': 'Beijing',
#   'Option C': 'Bangkok',
#   'Option D': 'Tokyo',
#   'Right Answer': 'D'},
#  {'Question': 'What is the square root of 144?',
#   'Option A': '10',
#   'Option B': '12',
#   'Option C': '14',
#   'Option D': '16',
#   'Right Answer': 'B'},
#  {'Question': 'What is the value of Pi rounded to two decimal places?',
#   'Option A': '3.12',
#   'Option B': '3.14',
#   'Option C': '3.16',
#   'Option D': '3.18',
#   'Right Answer': 'B'},
#  {'Question': 'Which component is responsible for long-term data storage?',
#   'Option A': 'RAM',
#   'Option B': 'CPU',
#   'Option C': 'HDD/SSD',
#   'Option D': 'GPU',
#   'Right Answer': 'C'}]

# %%
import random as rd
randomnolist=[]
for i in range(10):
    while True:
        random10no=r.randint(0,21)
        if random10no in randomnolist:
            continue
        else:
            randomnolist.append(random10no)
            break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       3 for i in range(10):
#       4     while True:
# ----> 5         random10no=r.randint(0,21)
#       6         if random10no in randomnolist:
#       7             continue
#
# NameError: name 'r' is not defined
